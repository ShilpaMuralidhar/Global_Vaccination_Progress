# %% [markdown]
# ## Import CSV

# %%
import pandas as pd
import numpy as np

# %%
wuenic = "../archive/2018_wuenic.csv"
wuenic_df = pd.read_csv(wuenic)
wuenic_df.head(5)
# Out:
#             Group Subgroup         Name  Year Vaccine  Coverage Vaccinated  \
# 0  UNICEF Regions     ROSA  Afghanistan  2018     BCG        78    941,000
# 1  UNICEF Regions     ROSA  Afghanistan  2018    DTP1        73    836,000
# 2  UNICEF Regions     ROSA  Afghanistan  2018    DTP3        66    756,000
# 3  UNICEF Regions     ROSA  Afghanistan  2018   Hepb3        66    756,000
# 4  UNICEF Regions     ROSA  Afghanistan  2018   Hepbb        18    217,000
#
#       Target                                             Source
# 0  1,207,000  WHO/UNICEF estimates of national immunization ...
# 1  1,146,000  WHO/UNICEF estimates of national immunization ...
# 2  1,146,000  WHO/UNICEF estimates of national immunization ...
# 3  1,146,000  WHO/UNICEF estimates of national immunization ...
# 4  1,207,000  WHO/UNICEF estimates of national immunization ...

# %% [markdown]
# ## Remove columns: Group and Source

# %%
wuenic_df.drop(['Group', 'Source'], axis=1, inplace= True)
wuenic_df
# Out:
#       Subgroup         Name  Year Vaccine  Coverage Vaccinated     Target
# 0         ROSA  Afghanistan  2018     BCG        78    941,000  1,207,000
# 1         ROSA  Afghanistan  2018    DTP1        73    836,000  1,146,000
# 2         ROSA  Afghanistan  2018    DTP3        66    756,000  1,146,000
# 3         ROSA  Afghanistan  2018   Hepb3        66    756,000  1,146,000
# 4         ROSA  Afghanistan  2018   Hepbb        18    217,000  1,207,000
# ...        ...          ...   ...     ...       ...        ...        ...
# 35569     ESAR     Zimbabwe  1997    DTP1        95    328,000    345,000
# 35570     ESAR     Zimbabwe  1997    DTP3        86    297,000    345,000
# 35571     ESAR     Zimbabwe  1997   Hepb3        16     55,000    345,000
# 35572     ESAR     Zimbabwe  1997    MCV1        84    290,000    345,000
# 35573     ESAR     Zimbabwe  1997    Pol3        86    297,000    345,000
#
# [35574 rows x 7 columns]

# %% [markdown]
# # Remove characters: comma, symbols

# %%
wuenic_df['Vaccinated'] = wuenic_df['Vaccinated'].replace(',', '', regex = True)\
                        .replace('<', '', regex = True).replace('>', '', regex = True).astype('object')
wuenic_df

# %%
wuenic_df['Target'] = wuenic_df['Target'].replace(',', '', regex = True)\
                    .replace('<', '', regex = True).replace('>', '', regex = True).astype('object')
wuenic_df
# Out:
#       Subgroup         Name  Year Vaccine  Coverage Vaccinated   Target
# 0         ROSA  Afghanistan  2018     BCG        78     941000  1207000
# 1         ROSA  Afghanistan  2018    DTP1        73     836000  1146000
# 2         ROSA  Afghanistan  2018    DTP3        66     756000  1146000
# 3         ROSA  Afghanistan  2018   Hepb3        66     756000  1146000
# 4         ROSA  Afghanistan  2018   Hepbb        18     217000  1207000
# ...        ...          ...   ...     ...       ...        ...      ...
# 35569     ESAR     Zimbabwe  1997    DTP1        95     328000   345000
# 35570     ESAR     Zimbabwe  1997    DTP3        86     297000   345000
# 35571     ESAR     Zimbabwe  1997   Hepb3        16      55000   345000
# 35572     ESAR     Zimbabwe  1997    MCV1        84     290000   345000
# 35573     ESAR     Zimbabwe  1997    Pol3        86     297000   345000
#
# [35574 rows x 7 columns]

# %% [markdown]
# # Identify missing values: As shown in Vaccinated and Target

# %%
wuenic_df.loc[32948]
# Out:
# Subgroup        EAPR
# Name          Tuvalu
# Year            2007
# Vaccine         RCV1
# Coverage          95
# Vaccinated         —
# Target             —
# Name: 32948, dtype: object

# %% [markdown]
# # Replace missing value symbol to None

# %%
wuenic_df['Vaccinated'].replace({'—': None},inplace =True)
wuenic_df['Target'].replace({'—': None},inplace =True)
wuenic_df
# Out:
#       Subgroup         Name  Year Vaccine  Coverage Vaccinated   Target
# 0         ROSA  Afghanistan  2018     BCG        78     941000  1207000
# 1         ROSA  Afghanistan  2018    DTP1        73     836000  1146000
# 2         ROSA  Afghanistan  2018    DTP3        66     756000  1146000
# 3         ROSA  Afghanistan  2018   Hepb3        66     756000  1146000
# 4         ROSA  Afghanistan  2018   Hepbb        18     217000  1207000
# ...        ...          ...   ...     ...       ...        ...      ...
# 35569     ESAR     Zimbabwe  1997    DTP1        95     328000   345000
# 35570     ESAR     Zimbabwe  1997    DTP3        86     297000   345000
# 35571     ESAR     Zimbabwe  1997   Hepb3        16      55000   345000
# 35572     ESAR     Zimbabwe  1997    MCV1        84     290000   345000
# 35573     ESAR     Zimbabwe  1997    Pol3        86     297000   345000
#
# [35574 rows x 7 columns]

# %% [markdown]
# # Check if missing values are changed to None. Example given below

# %%
wuenic_df.loc[32948]
# Out:
# Subgroup        EAPR
# Name          Tuvalu
# Year            2007
# Vaccine         RCV1
# Coverage          95
# Vaccinated      None
# Target          None
# Name: 32948, dtype: object

# %% [markdown]
# # Drop null values and rename column "Name to "Country"

# %%
clean_df= wuenic_df.dropna().rename(columns={'Name': 'Country'})
clean_df
# Out:
#       Subgroup      Country  Year Vaccine  Coverage Vaccinated   Target
# 0         ROSA  Afghanistan  2018     BCG        78     941000  1207000
# 1         ROSA  Afghanistan  2018    DTP1        73     836000  1146000
# 2         ROSA  Afghanistan  2018    DTP3        66     756000  1146000
# 3         ROSA  Afghanistan  2018   Hepb3        66     756000  1146000
# 4         ROSA  Afghanistan  2018   Hepbb        18     217000  1207000
# ...        ...          ...   ...     ...       ...        ...      ...
# 35569     ESAR     Zimbabwe  1997    DTP1        95     328000   345000
# 35570     ESAR     Zimbabwe  1997    DTP3        86     297000   345000
# 35571     ESAR     Zimbabwe  1997   Hepb3        16      55000   345000
# 35572     ESAR     Zimbabwe  1997    MCV1        84     290000   345000
# 35573     ESAR     Zimbabwe  1997    Pol3        86     297000   345000
#
# [33406 rows x 7 columns]

# %% [markdown]
# # Insert index column with column names "Year, Vaccine and Country" as Index

# %%
Combined = clean_df['Year'].astype(str)+ clean_df['Vaccine']+clean_df['Country']
clean_df.insert(0, 'Index', Combined, allow_duplicates = False)

clean_df
# Out:
#                       Index Subgroup      Country  Year Vaccine  Coverage  \
# 0        2018BCGAfghanistan     ROSA  Afghanistan  2018     BCG        78
# 1       2018DTP1Afghanistan     ROSA  Afghanistan  2018    DTP1        73
# 2       2018DTP3Afghanistan     ROSA  Afghanistan  2018    DTP3        66
# 3      2018Hepb3Afghanistan     ROSA  Afghanistan  2018   Hepb3        66
# 4      2018HepbbAfghanistan     ROSA  Afghanistan  2018   Hepbb        18
# ...                     ...      ...          ...   ...     ...       ...
# 35569      1997DTP1Zimbabwe     ESAR     Zimbabwe  1997    DTP1        95
# 35570      1997DTP3Zimbabwe     ESAR     Zimbabwe  1997    DTP3        86
# 35571     1997Hepb3Zimbabwe     ESAR     Zimbabwe  1997   Hepb3        16
# 35572      1997MCV1Zimbabwe     ESAR     Zimbabwe  1997    MCV1        84
# 35573      1997Pol3Zimbabwe     ESAR     Zimbabwe  1997    Pol3        86
#
#       Vaccinated   Target
# 0         941000  1207000
# 1         836000  1146000
# 2         756000  1146000
# 3         756000  1146000
# 4         217000  1207000
# ...          ...      ...
# 35569     328000   345000
# 35570     297000   345000
# 35571      55000   345000
# 35572     290000   345000
# 35573     297000   345000
#
# [33406 rows x 8 columns]

# %% [markdown]
# # Re-organise columns

# %%
clean_wuenic = pd.DataFrame(clean_df, columns= ['Index', 'Country', "Year","Vaccine", "Subgroup","Coverage",\
                                                "Vaccinated","Target"])
clean_wuenic
# Out:
#                       Index      Country  Year Vaccine Subgroup  Coverage  \
# 0        2018BCGAfghanistan  Afghanistan  2018     BCG     ROSA        78
# 1       2018DTP1Afghanistan  Afghanistan  2018    DTP1     ROSA        73
# 2       2018DTP3Afghanistan  Afghanistan  2018    DTP3     ROSA        66
# 3      2018Hepb3Afghanistan  Afghanistan  2018   Hepb3     ROSA        66
# 4      2018HepbbAfghanistan  Afghanistan  2018   Hepbb     ROSA        18
# ...                     ...          ...   ...     ...      ...       ...
# 35569      1997DTP1Zimbabwe     Zimbabwe  1997    DTP1     ESAR        95
# 35570      1997DTP3Zimbabwe     Zimbabwe  1997    DTP3     ESAR        86
# 35571     1997Hepb3Zimbabwe     Zimbabwe  1997   Hepb3     ESAR        16
# 35572      1997MCV1Zimbabwe     Zimbabwe  1997    MCV1     ESAR        84
# 35573      1997Pol3Zimbabwe     Zimbabwe  1997    Pol3     ESAR        86
#
#       Vaccinated   Target
# 0         941000  1207000
# 1         836000  1146000
# 2         756000  1146000
# 3         756000  1146000
# 4         217000  1207000
# ...          ...      ...
# 35569     328000   345000
# 35570     297000   345000
# 35571      55000   345000
# 35572     290000   345000
# 35573     297000   345000
#
# [33406 rows x 8 columns]

# %%
pd.clean_wuenic

# %% [markdown]
# # The End
