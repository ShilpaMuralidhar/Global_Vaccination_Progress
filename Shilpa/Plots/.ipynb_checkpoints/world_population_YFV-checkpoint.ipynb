# %%
import pandas as pd
import numpy as np
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
world_pop = "/Users/shilpa/Desktop/Desktop/RICE_DATA/Global_Vaccination_Progress/Shilpa/Plots/worldpop.csv"
world_pop_df = pd.read_csv(world_pop)

world_pop_df.head(5)
# Out:
#   Country Name       1960       1961       1962       1963       1964  \
# 0        Aruba    54211.0    55438.0    56225.0    56695.0    57032.0
# 1  Afghanistan  8996973.0  9169410.0  9351441.0  9543205.0  9744781.0
# 2       Angola  5454933.0  5531472.0  5608539.0  5679458.0  5735044.0
# 3      Albania  1608800.0  1659800.0  1711319.0  1762621.0  1814135.0
# 4      Andorra    13411.0    14375.0    15370.0    16412.0    17469.0
#
#         1965        1966        1967        1968  ...        2009        2010  \
# 0    57360.0     57715.0     58055.0     58386.0  ...    101455.0    101669.0
# 1  9956320.0  10174836.0  10399926.0  10637063.0  ...  28394813.0  29185507.0
# 2  5770570.0   5781214.0   5774243.0   5771652.0  ...  22514281.0  23356246.0
# 3  1864791.0   1914573.0   1965598.0   2022272.0  ...   2927519.0   2913021.0
# 4    18549.0     19647.0     20758.0     21890.0  ...     84463.0     84449.0
#
#          2011        2012        2013        2014        2015        2016  \
# 0    102046.0    102560.0    103159.0    103774.0    104341.0    104872.0
# 1  30117413.0  31161376.0  32269589.0  33370794.0  34413603.0  35383128.0
# 2  24220661.0  25107931.0  26015780.0  26941779.0  27884381.0  28842484.0
# 3   2905195.0   2900401.0   2895092.0   2889104.0   2880703.0   2876101.0
# 4     83747.0     82427.0     80774.0     79213.0     78011.0     77297.0
#
#          2017        2018
# 0    105366.0    105845.0
# 1  36296400.0  37172386.0
# 2  29816748.0  30809762.0
# 3   2873457.0   2866376.0
# 4     77001.0     77006.0
#
# [5 rows x 60 columns]

# %%
wuenic_merge = "clean_wuenic.csv"
wuenic_merge_df = pd.read_csv(wuenic_merge)

wuenic_merge_df.head(5)
# Out:
#    Unnamed: 0                 Index      Country  Year Vaccine Subgroup  \
# 0           0    2018BCGAfghanistan  Afghanistan  2018     BCG     ROSA
# 1           1   2018DTP1Afghanistan  Afghanistan  2018    DTP1     ROSA
# 2           2   2018DTP3Afghanistan  Afghanistan  2018    DTP3     ROSA
# 3           3  2018Hepb3Afghanistan  Afghanistan  2018   Hepb3     ROSA
# 4           4  2018HepbbAfghanistan  Afghanistan  2018   Hepbb     ROSA
#
#    Coverage  Vaccinated   Target
# 0        78      941000  1207000
# 1        73      836000  1146000
# 2        66      756000  1146000
# 3        66      756000  1146000
# 4        18      217000  1207000

# %%
a = world_pop_df.drop(columns= ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', 
                            '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980','1981', '1982',
                            '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
                            '1995', '1996'])
df_dropped = pd.DataFrame(a)
df_dropped
# Out:
#      Country Name        1997        1998        1999        2000        2001  \
# 0           Aruba     85451.0     87277.0     89005.0     90853.0     92898.0
# 1     Afghanistan  19357126.0  19737765.0  20170844.0  20779953.0  21606988.0
# 2          Angola  14871570.0  15359601.0  15866869.0  16395473.0  16945753.0
# 3         Albania   3148281.0   3128530.0   3108778.0   3089027.0   3060173.0
# 4         Andorra     64327.0     64142.0     64370.0     65390.0     67341.0
# ..            ...         ...         ...         ...         ...         ...
# 259        Kosovo   2086000.0   1966000.0   1762000.0   1700000.0   1701154.0
# 260   Yemen, Rep.  15975668.0  16450310.0  16921149.0  17409072.0  17918373.0
# 261  South Africa  42987461.0  43682260.0  44338543.0  44967708.0  45571274.0
# 262        Zambia   9597609.0   9866476.0  10140561.0  10415944.0  10692193.0
# 263      Zimbabwe  11653242.0  11747072.0  11822719.0  11881477.0  11923914.0
#
#            2002        2003        2004        2005  ...        2009  \
# 0       94992.0     97017.0     98737.0    100031.0  ...    101455.0
# 1    22600770.0  23680871.0  24726684.0  25654277.0  ...  28394813.0
# 2    17519417.0  18121479.0  18758145.0  19433602.0  ...  22514281.0
# 3     3051010.0   3039616.0   3026939.0   3011487.0  ...   2927519.0
# 4       70049.0     73182.0     76244.0     78867.0  ...     84463.0
# ..          ...         ...         ...         ...  ...         ...
# 259   1702310.0   1703466.0   1704622.0   1705780.0  ...   1761474.0
# 260  18443691.0  18985000.0  19540098.0  20107409.0  ...  22516460.0
# 261  46150913.0  46719196.0  47291610.0  47880601.0  ...  50477011.0
# 262  10971698.0  11256743.0  11550642.0  11856247.0  ...  13215139.0
# 263  11954290.0  11982224.0  12019912.0  12076699.0  ...  12526968.0
#
#            2010        2011        2012        2013        2014        2015  \
# 0      101669.0    102046.0    102560.0    103159.0    103774.0    104341.0
# 1    29185507.0  30117413.0  31161376.0  32269589.0  33370794.0  34413603.0
# 2    23356246.0  24220661.0  25107931.0  26015780.0  26941779.0  27884381.0
# 3     2913021.0   2905195.0   2900401.0   2895092.0   2889104.0   2880703.0
# 4       84449.0     83747.0     82427.0     80774.0     79213.0     78011.0
# ..          ...         ...         ...         ...         ...         ...
# 259   1775680.0   1791000.0   1805200.0   1824100.0   1821800.0   1801800.0
# 260  23154855.0  23807588.0  24473178.0  25147109.0  25823485.0  26497889.0
# 261  51216964.0  52004172.0  52834005.0  53689236.0  54545991.0  55386367.0
# 262  13605984.0  14023193.0  14465121.0  14926504.0  15399753.0  15879361.0
# 263  12697723.0  12894316.0  13115131.0  13350356.0  13586681.0  13814629.0
#
#            2016        2017        2018
# 0      104872.0    105366.0    105845.0
# 1    35383128.0  36296400.0  37172386.0
# 2    28842484.0  29816748.0  30809762.0
# 3     2876101.0   2873457.0   2866376.0
# 4       77297.0     77001.0     77006.0
# ..          ...         ...         ...
# 259   1816200.0   1830700.0   1845300.0
# 260  27168210.0  27834821.0  28498687.0
# 261  56203654.0  57000451.0  57779622.0
# 262  16363507.0  16853688.0  17351822.0
# 263  14030390.0  14236745.0  14439018.0
#
# [264 rows x 23 columns]

# %%
df2=pd.melt(df_dropped,id_vars=['Country Name'],var_name='Year', value_name='values')
df2
# Out:
#       Country Name  Year      values
# 0            Aruba  1997     85451.0
# 1      Afghanistan  1997  19357126.0
# 2           Angola  1997  14871570.0
# 3          Albania  1997   3148281.0
# 4          Andorra  1997     64327.0
# ...            ...   ...         ...
# 5803        Kosovo  2018   1845300.0
# 5804   Yemen, Rep.  2018  28498687.0
# 5805  South Africa  2018  57779622.0
# 5806        Zambia  2018  17351822.0
# 5807      Zimbabwe  2018  14439018.0
#
# [5808 rows x 3 columns]

# %%
df_sorted= df2.sort_values(['Country Name','Year'], ascending= [True, True])
renamed_df_sorted = df_sorted.rename(columns={'Country Name': 'Country'})
renamed_df_sorted
# Out:
#           Country  Year      values
# 1     Afghanistan  1997  19357126.0
# 265   Afghanistan  1998  19737765.0
# 529   Afghanistan  1999  20170844.0
# 793   Afghanistan  2000  20779953.0
# 1057  Afghanistan  2001  21606988.0
# ...           ...   ...         ...
# 4751     Zimbabwe  2014  13586681.0
# 5015     Zimbabwe  2015  13814629.0
# 5279     Zimbabwe  2016  14030390.0
# 5543     Zimbabwe  2017  14236745.0
# 5807     Zimbabwe  2018  14439018.0
#
# [5808 rows x 3 columns]

# %%
# df_sorted_Afghanistan = renamed_df_sorted[renamed_df_sorted['Country'] == 'Afghanistan']
# df_sorted_Afghanistan['values'].astype('object')
# df_sorted_Afghanistan_object = pd.DataFrame(df_sorted_Afghanistan)
# df_sorted_Afghanistan_object.head(5)

# %%
# df_sorted_Afghanistan_object.types()

# %%
YFV_only = wuenic_merge_df[wuenic_merge_df['Vaccine'] == 'YFV']
YFV_only.dropna()
# Out:
#        Unnamed: 0                                      Index  \
# 561           747                              2018YFVAngola
# 572           758                              2017YFVAngola
# 583           769                              2016YFVAngola
# 594           780                              2015YFVAngola
# 604           790                              2014YFVAngola
# ...           ...                                        ...
# 32685       34853  2004YFVVenezuela (Bolivarian Republic of)
# 32695       34863  2003YFVVenezuela (Bolivarian Republic of)
# 32705       34873  2002YFVVenezuela (Bolivarian Republic of)
# 32715       34883  2001YFVVenezuela (Bolivarian Republic of)
# 32725       34893  2000YFVVenezuela (Bolivarian Republic of)
#
#                                   Country  Year Vaccine Subgroup  Coverage  \
# 561                                Angola  2018     YFV     ESAR        28
# 572                                Angola  2017     YFV     ESAR        28
# 583                                Angola  2016     YFV     ESAR        24
# 594                                Angola  2015     YFV     ESAR        43
# 604                                Angola  2014     YFV     ESAR        48
# ...                                   ...   ...     ...      ...       ...
# 32685  Venezuela (Bolivarian Republic of)  2004     YFV     LACR        94
# 32695  Venezuela (Bolivarian Republic of)  2003     YFV     LACR        82
# 32705  Venezuela (Bolivarian Republic of)  2002     YFV     LACR        27
# 32715  Venezuela (Bolivarian Republic of)  2001     YFV     LACR        28
# 32725  Venezuela (Bolivarian Republic of)  2000     YFV     LACR        17
#
#        Vaccinated   Target
# 561        331000  1181000
# 572        323000  1155000
# 583        271000  1130000
# 594        475000  1105000
# 604        518000  1080000
# ...           ...      ...
# 32685      541000   576000
# 32695      470000   573000
# 32705      154000   571000
# 32715      159000   568000
# 32725       96000   566000
#
# [604 rows x 9 columns]

# %%
df_YFV = pd.merge(YFV_only, renamed_df_sorted, on='Country', how='inner')
df_YFV.drop(columns=['Year_y'])
# Out:
#        Unnamed: 0                       Index              Country  Year_x  \
# 0             747               2018YFVAngola               Angola    2018
# 1             747               2018YFVAngola               Angola    2018
# 2             747               2018YFVAngola               Angola    2018
# 3             747               2018YFVAngola               Angola    2018
# 4             747               2018YFVAngola               Angola    2018
# ...           ...                         ...                  ...     ...
# 11369       32253  1998YFVTrinidad and Tobago  Trinidad and Tobago    1998
# 11370       32253  1998YFVTrinidad and Tobago  Trinidad and Tobago    1998
# 11371       32253  1998YFVTrinidad and Tobago  Trinidad and Tobago    1998
# 11372       32253  1998YFVTrinidad and Tobago  Trinidad and Tobago    1998
# 11373       32253  1998YFVTrinidad and Tobago  Trinidad and Tobago    1998
#
#       Vaccine Subgroup  Coverage  Vaccinated   Target      values
# 0         YFV     ESAR        28      331000  1181000  14871570.0
# 1         YFV     ESAR        28      331000  1181000  15359601.0
# 2         YFV     ESAR        28      331000  1181000  15866869.0
# 3         YFV     ESAR        28      331000  1181000  16395473.0
# 4         YFV     ESAR        28      331000  1181000  16945753.0
# ...       ...      ...       ...         ...      ...         ...
# 11369     YFV     LACR        91       17000    18000   1362342.0
# 11370     YFV     LACR        91       17000    18000   1370328.0
# 11371     YFV     LACR        91       17000    18000   1377564.0
# 11372     YFV     LACR        91       17000    18000   1384072.0
# 11373     YFV     LACR        91       17000    18000   1389858.0
#
# [11374 rows x 10 columns]

# %%
df_YFV.to_csv('../Plots/df_YFV_All_countries.csv')
