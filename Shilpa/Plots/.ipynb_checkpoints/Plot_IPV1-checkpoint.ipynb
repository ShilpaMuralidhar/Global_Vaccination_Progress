# %%
import pandas as pd
import numpy as np
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
wuenic = "/Users/shilpa/Desktop/Desktop/RICE_DATA/Global_Vaccination_Progress/Shilpa/Plots/df_IPV1_All_countries.csv"
IPV1 = pd.read_csv(wuenic)
IPV1.head(5)
df_IPV1= IPV1.sort_values(['year'], ascending= True)
df_IPV1
# Out:
#       Unnamed: 0     0  Unnamed: 0.1                       Index  \
# 0            132   132           203             2015IPV1Albania
# 1032        6790  6790         27990             2015IPV1Senegal
# 1031        6724  6724         27762        2015IPV1Saudi Arabia
# 1030        6482  6482         26297  2015IPV1Russian Federation
# 1029        6394  6394         25288               2015IPV1Qatar
# ...          ...   ...           ...                         ...
# 6858        2933  2933         12213               2018IPV1Ghana
# 6859        2955  2955         12585             2018IPV1Grenada
# 6860        3043  3043         12756           2018IPV1Guatemala
# 6842        1855  1855          6451               2018IPV1China
# 8601        8601  8601         35261              2018IPV1Zambia
#
#                  country  year Vaccine Subgroup  Coverage  Vaccinated  \
# 0                Albania  2015    IPV1   CEECIS        99       35000
# 1032             Senegal  2015    IPV1     WCAR        81      414000
# 1031        Saudi Arabia  2015    IPV1     MENA        98      595000
# 1030  Russian Federation  2015    IPV1   CEECIS        97     1829000
# 1029               Qatar  2015    IPV1     MENA        96       24000
# ...                  ...   ...     ...      ...       ...         ...
# 6858               Ghana  2018    IPV1     WCAR        55      465000
# 6859             Grenada  2018    IPV1     LACR        96        2000
# 6860           Guatemala  2018    IPV1     LACR        94      390000
# 6842               China  2018    IPV1     EAPR        99    16496000
# 8601              Zambia  2018    IPV1     ESAR        36      216000
#
#         Target      values
# 0        35000     3148281
# 1032    511000    13033809
# 1031    607000    28267685
# 1030   1885000   142960868
# 1029     25000     2035871
# ...        ...         ...
# 6858    845000    21272323
# 6859      2000      104347
# 6860    415000    12796925
# 6842  16662000  1296075000
# 8601    601000    17351822
#
# [8602 rows x 12 columns]

# %%
df_IPV1.to_csv('../Plots/df_IPV1_All_countries.csv')

# %%
# df_Hib3.fillna("")

# %%
# df_Hib3.fillna(0)

# %%
# df_BCG['values'].replace({'NaN': 0},inplace =True)
# df_BCG['Target'].replace({'—': None},inplace =True)
# df_BCG

# %%
# wuenic_df_Hib3= df_Hib3.rename(columns={'Country': 'country','Year_x': 'year' })
# wuenic_df_Hib3

# %%
# wuenic_df_Hib3

# %%
# wuenic_df_Hib3.to_csv('../Plots/wuenic_df_Hib3_All_countries.csv')

# %%
# wuenic_df['Vaccinated'] = wuenic_df['Vaccinated'].replace(',', '', regex = True)\
#                         .replace('<', '', regex = True).replace('>', '', regex = True).astype('object')
# wuenic_df

# %%
#wuenic_df['Target'] = wuenic_df['Target'].replace(',', '', regex = True)\
                    #.replace('<', '', regex = True).replace('>', '', regex = True).astype('object')
#wuenic_df

# %%
# wuenic_df['Vaccinated'].replace({'—': None},inplace =True)
# wuenic_df['Target'].replace({'—': None},inplace =True)
# wuenic_df

# %%
# convert_Vaccinated= wuenic_df['Vaccinated'] = pd.to_numeric(wuenic_df['Vaccinated'])
# convert_Vaccinated

# %%
# convert_Target = wuenic_df['Target'] = pd.to_numeric(wuenic_df['Target'])
# convert_Target

# %%
# a = "/Users/shilpa/Desktop/Desktop/RICE_DATA/Global_Vaccination_Progress/Shilpa/Plots/clean_data/life_stack_reduced.csv"
# a_df = pd.read_csv(a)
# a_df.head(5)

# %%
# df_new = pd.concat([wuenic_df, a_df], axis=1)
# df_new.head(3)

# %%
# renamed = wuenic_df.rename(columns={"Name": "country", "Year": "year"})
# renamed.head(5)

# %%
dataset = df_IPV1
x_column = 'Target'
y_column = 'Coverage'
size_column = 'values'
bubble_column = 'country'
time_column = 'year'

# %%
# Get the years in the dataset
years = dataset[time_column].unique()

# Make the grid
grid = pd.DataFrame()
col_name_template = '{year}+{header}_grid'
for year in years:
    dataset_by_year = dataset[(dataset['year'] == int(year))]
    for col_name in [x_column, y_column, bubble_column]:
        # Each column name is unique
        temp = col_name_template.format(
            year=year, header=col_name
        )
        if dataset_by_year[col_name].size != 0:
            grid = grid.append({'value': list(dataset_by_year[col_name]), 'key': temp}, 
                               ignore_index=True)

grid.sample(5)
# Out:
#                    key                                              value
# 10  2018+Coverage_grid  [41, 79, 46, 99, 99, 57, 35, 96, 91, 89, 81, 1...
# 5    2016+country_grid  [Philippines, Myanmar, Panama, Oman, Peru, Nig...
# 7   2017+Coverage_grid  [60, 12, 16, 99, 85, 90, 99, 67, 96, 32, 95, 1...
# 8    2017+country_grid  [Mozambique, Myanmar, Nepal, Nicaragua, Niger,...
# 9     2018+Target_grid  [2148000, 990000, 5000, 131000, 91000, 6977000...

# %%
# Define figure
figure = {
    'data': [],
    'layout': {},
    'frames': []
}

# Get the earliest year
year = min(years)

# Make the trace
trace = {
    'x': grid.loc[grid['key']==col_name_template.format(
        year=year, header=x_column
    ), 'value'].values[0], 
    'y': grid.loc[grid['key']==col_name_template.format(
        year=year, header=y_column
    ), 'value'].values[0],
    'mode': 'markers',
    'text': grid.loc[grid['key']==col_name_template.format(
        year=year, header=bubble_column
    ), 'value'].values[0]
}
# Append the trace to the figure
figure['data'].append(trace)

# Plot the figure
plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# //anaconda3/lib/python3.7/site-packages/plotly/offline/offline.py:156: UserWarning:
#
#
# Unrecognized config options supplied: ['scrollzoom']
# <div>
#
#
#             <div id="f8797e64-afeb-41e0-a2a8-e6d39efda8ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f8797e64-afeb-41e0-a2a8-e6d39efda8ce")) {
#                     Plotly.newPlot(
#                         'f8797e64-afeb-41e0-a2a8-e6d39efda8ce',
#                         [{"mode": "markers", "text": ["Albania", "Senegal", "Saudi Arabia", "Russian Federation", "Qatar", "Peru", "Panama", "Pakistan", "Oman", "Nigeria", "Serbia", "Niger", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Mauritania", "Maldives", "Madagascar", "Libya", "Nicaragua", "Lebanon", "Seychelles", "Solomon Islands", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Vanuatu", "United Arab Emirates", "Singapore", "Ukraine", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "South Sudan", "South Africa", "Turkey", "Bhutan", "Kuwait", "Kazakhstan", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Vanuatu", "United Arab Emirates", "Ukraine", "Turkey", "Belize", "Tunisia", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "South Sudan", "South Africa", "Solomon Islands", "Singapore", "Trinidad and Tobago", "Kiribati", "Benin", "Bosnia and Herzegovina", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Grenada", "Georgia", "Bhutan", "Ecuador", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Brazil", "Botswana", "Dominican Republic", "Seychelles", "Bosnia and Herzegovina", "Brazil", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Botswana", "Vanuatu", "Ukraine", "Turkey", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "United Arab Emirates", "South Sudan", "Brazil", "Cameroon", "Lebanon", "Kuwait", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Burundi", "Guyana", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Guinea", "Botswana", "South Africa", "Singapore", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Kuwait", "Grenada", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Georgia", "Solomon Islands", "Lebanon", "Madagascar", "Seychelles", "Serbia", "Senegal", "Saudi Arabia", "Russian Federation", "Qatar", "Peru", "Panama", "Pakistan", "Libya", "Oman", "Niger", "Nicaragua", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Mauritania", "Maldives", "Nigeria", "Serbia", "Senegal", "Saudi Arabia", "Vanuatu", "United Arab Emirates", "Ukraine", "Turkey", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Albania", "Sudan", "South Sudan", "South Africa", "Solomon Islands", "Singapore", "Seychelles", "Serbia", "Senegal", "Saudi Arabia", "Russian Federation", "Sri Lanka", "Qatar", "Algeria", "Bahrain", "Guyana", "Guinea", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Antigua and Barbuda", "Chad", "Cameroon", "Burundi", "Brazil", "Botswana", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Central African Republic", "Honduras", "Peru", "Pakistan", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Guinea", "Cameroon", "Brazil", "Botswana", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Burundi", "Panama", "Guyana", "India", "Oman", "Nigeria", "Niger", "Nicaragua", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Honduras", "Mauritania", "Madagascar", "Libya", "Lebanon", "Kuwait", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "Maldives", "India", "Israel", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Jamaica", "Cote d'Ivoire", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Brazil ...

# %%
# Get the max and min range of both axes
xmin = min(np.log10(dataset[x_column]))*0.98
xmax = max(np.log10(dataset[x_column]))*1.02
ymin = min(dataset[y_column])*0.75
ymax = max(dataset[y_column])*1.25

# Modify the layout
figure['layout']['xaxis'] = {'title': 'Target', 'type': 'log', 
                             'range': [xmin, xmax]}   
figure['layout']['yaxis'] = {'title': '%Vaccinated', 
                             'range': [ymin, ymax]} 
figure['layout']['title'] = 'Global IPV1 Vaccination'
figure['layout']['showlegend'] = False
figure['layout']['hovermode'] = 'closest'
plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# <div>
#
#
#             <div id="60153c57-2841-4442-8aef-2470feff291d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("60153c57-2841-4442-8aef-2470feff291d")) {
#                     Plotly.newPlot(
#                         '60153c57-2841-4442-8aef-2470feff291d',
#                         [{"mode": "markers", "text": ["Albania", "Senegal", "Saudi Arabia", "Russian Federation", "Qatar", "Peru", "Panama", "Pakistan", "Oman", "Nigeria", "Serbia", "Niger", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Mauritania", "Maldives", "Madagascar", "Libya", "Nicaragua", "Lebanon", "Seychelles", "Solomon Islands", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Vanuatu", "United Arab Emirates", "Singapore", "Ukraine", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "South Sudan", "South Africa", "Turkey", "Bhutan", "Kuwait", "Kazakhstan", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Vanuatu", "United Arab Emirates", "Ukraine", "Turkey", "Belize", "Tunisia", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "South Sudan", "South Africa", "Solomon Islands", "Singapore", "Trinidad and Tobago", "Kiribati", "Benin", "Bosnia and Herzegovina", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Grenada", "Georgia", "Bhutan", "Ecuador", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Brazil", "Botswana", "Dominican Republic", "Seychelles", "Bosnia and Herzegovina", "Brazil", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Botswana", "Vanuatu", "Ukraine", "Turkey", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "United Arab Emirates", "South Sudan", "Brazil", "Cameroon", "Lebanon", "Kuwait", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Burundi", "Guyana", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Guinea", "Botswana", "South Africa", "Singapore", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Kuwait", "Grenada", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Georgia", "Solomon Islands", "Lebanon", "Madagascar", "Seychelles", "Serbia", "Senegal", "Saudi Arabia", "Russian Federation", "Qatar", "Peru", "Panama", "Pakistan", "Libya", "Oman", "Niger", "Nicaragua", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Mauritania", "Maldives", "Nigeria", "Serbia", "Senegal", "Saudi Arabia", "Vanuatu", "United Arab Emirates", "Ukraine", "Turkey", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Albania", "Sudan", "South Sudan", "South Africa", "Solomon Islands", "Singapore", "Seychelles", "Serbia", "Senegal", "Saudi Arabia", "Russian Federation", "Sri Lanka", "Qatar", "Algeria", "Bahrain", "Guyana", "Guinea", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Antigua and Barbuda", "Chad", "Cameroon", "Burundi", "Brazil", "Botswana", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Central African Republic", "Honduras", "Peru", "Pakistan", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Guinea", "Cameroon", "Brazil", "Botswana", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Burundi", "Panama", "Guyana", "India", "Oman", "Nigeria", "Niger", "Nicaragua", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Honduras", "Mauritania", "Madagascar", "Libya", "Lebanon", "Kuwait", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "Maldives", "India", "Israel", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Jamaica", "Cote d'Ivoire", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Brazil ...

# %%
for year in years:
    # Make a frame for each year
    frame = {'data': [], 'name': str(year)}
    
    # Make a trace for each frame
    trace = {
        'x': grid.loc[grid['key']==col_name_template.format(
            year=year, header=x_column
        ), 'value'].values[0],
        'y': grid.loc[grid['key']==col_name_template.format(
            year=year, header=y_column
        ), 'value'].values[0],
        'mode': 'markers',
        'text': grid.loc[grid['key']==col_name_template.format(
            year=year, header=bubble_column
        ), 'value'].values[0],
        'type': 'scatter'
    }
    # Add trace to the frame
    frame['data'].append(trace)
    # Add frame to the figure
    figure['frames'].append(frame) 

plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# <div>
#
#
#             <div id="038d8724-4e47-4616-bcf5-a57d36d69bbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("038d8724-4e47-4616-bcf5-a57d36d69bbd")) {
#                     Plotly.newPlot(
#                         '038d8724-4e47-4616-bcf5-a57d36d69bbd',
#                         [{"mode": "markers", "text": ["Albania", "Senegal", "Saudi Arabia", "Russian Federation", "Qatar", "Peru", "Panama", "Pakistan", "Oman", "Nigeria", "Serbia", "Niger", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Mauritania", "Maldives", "Madagascar", "Libya", "Nicaragua", "Lebanon", "Seychelles", "Solomon Islands", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Vanuatu", "United Arab Emirates", "Singapore", "Ukraine", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "South Sudan", "South Africa", "Turkey", "Bhutan", "Kuwait", "Kazakhstan", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Vanuatu", "United Arab Emirates", "Ukraine", "Turkey", "Belize", "Tunisia", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "South Sudan", "South Africa", "Solomon Islands", "Singapore", "Trinidad and Tobago", "Kiribati", "Benin", "Bosnia and Herzegovina", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Grenada", "Georgia", "Bhutan", "Ecuador", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Brazil", "Botswana", "Dominican Republic", "Seychelles", "Bosnia and Herzegovina", "Brazil", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Botswana", "Vanuatu", "Ukraine", "Turkey", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "United Arab Emirates", "South Sudan", "Brazil", "Cameroon", "Lebanon", "Kuwait", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Burundi", "Guyana", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Guinea", "Botswana", "South Africa", "Singapore", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Kuwait", "Grenada", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Georgia", "Solomon Islands", "Lebanon", "Madagascar", "Seychelles", "Serbia", "Senegal", "Saudi Arabia", "Russian Federation", "Qatar", "Peru", "Panama", "Pakistan", "Libya", "Oman", "Niger", "Nicaragua", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Mauritania", "Maldives", "Nigeria", "Serbia", "Senegal", "Saudi Arabia", "Vanuatu", "United Arab Emirates", "Ukraine", "Turkey", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Albania", "Sudan", "South Sudan", "South Africa", "Solomon Islands", "Singapore", "Seychelles", "Serbia", "Senegal", "Saudi Arabia", "Russian Federation", "Sri Lanka", "Qatar", "Algeria", "Bahrain", "Guyana", "Guinea", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Antigua and Barbuda", "Chad", "Cameroon", "Burundi", "Brazil", "Botswana", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Central African Republic", "Honduras", "Peru", "Pakistan", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Guinea", "Cameroon", "Brazil", "Botswana", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Burundi", "Panama", "Guyana", "India", "Oman", "Nigeria", "Niger", "Nicaragua", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Honduras", "Mauritania", "Madagascar", "Libya", "Lebanon", "Kuwait", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "Maldives", "India", "Israel", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Jamaica", "Cote d'Ivoire", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Brazil ...

# %%
figure['layout']['sliders'] = {
    'args': [
        'slider.value', {
            'duration': 400,
            'ease': 'cubic-in-out'
        }
    ],
    'initialValue': min(years),
    'plotlycommand': 'animate',
    'values': years,
    'visible': True
}
sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Year:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': []
}

from bubbly.bubbly import add_slider_steps

for year in years:
    add_slider_steps(sliders_dict, year)
    
figure['layout']['sliders'] = [sliders_dict]
plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# <div>
#
#
#             <div id="3b68bb61-59a5-47f8-a8de-54ab6c1bd5cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3b68bb61-59a5-47f8-a8de-54ab6c1bd5cf")) {
#                     Plotly.newPlot(
#                         '3b68bb61-59a5-47f8-a8de-54ab6c1bd5cf',
#                         [{"mode": "markers", "text": ["Albania", "Senegal", "Saudi Arabia", "Russian Federation", "Qatar", "Peru", "Panama", "Pakistan", "Oman", "Nigeria", "Serbia", "Niger", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Mauritania", "Maldives", "Madagascar", "Libya", "Nicaragua", "Lebanon", "Seychelles", "Solomon Islands", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Vanuatu", "United Arab Emirates", "Singapore", "Ukraine", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "South Sudan", "South Africa", "Turkey", "Bhutan", "Kuwait", "Kazakhstan", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Vanuatu", "United Arab Emirates", "Ukraine", "Turkey", "Belize", "Tunisia", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "South Sudan", "South Africa", "Solomon Islands", "Singapore", "Trinidad and Tobago", "Kiribati", "Benin", "Bosnia and Herzegovina", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Grenada", "Georgia", "Bhutan", "Ecuador", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Brazil", "Botswana", "Dominican Republic", "Seychelles", "Bosnia and Herzegovina", "Brazil", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Botswana", "Vanuatu", "Ukraine", "Turkey", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "United Arab Emirates", "South Sudan", "Brazil", "Cameroon", "Lebanon", "Kuwait", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Burundi", "Guyana", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Guinea", "Botswana", "South Africa", "Singapore", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Kuwait", "Grenada", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Georgia", "Solomon Islands", "Lebanon", "Madagascar", "Seychelles", "Serbia", "Senegal", "Saudi Arabia", "Russian Federation", "Qatar", "Peru", "Panama", "Pakistan", "Libya", "Oman", "Niger", "Nicaragua", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Mauritania", "Maldives", "Nigeria", "Serbia", "Senegal", "Saudi Arabia", "Vanuatu", "United Arab Emirates", "Ukraine", "Turkey", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Albania", "Sudan", "South Sudan", "South Africa", "Solomon Islands", "Singapore", "Seychelles", "Serbia", "Senegal", "Saudi Arabia", "Russian Federation", "Sri Lanka", "Qatar", "Algeria", "Bahrain", "Guyana", "Guinea", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Antigua and Barbuda", "Chad", "Cameroon", "Burundi", "Brazil", "Botswana", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Central African Republic", "Honduras", "Peru", "Pakistan", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Guinea", "Cameroon", "Brazil", "Botswana", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Burundi", "Panama", "Guyana", "India", "Oman", "Nigeria", "Niger", "Nicaragua", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Honduras", "Mauritania", "Madagascar", "Libya", "Lebanon", "Kuwait", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "Maldives", "India", "Israel", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Jamaica", "Cote d'Ivoire", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Brazil ...

# %%
figure['layout']['updatemenus'] = [
    {
        'buttons': [
            {
                'args': [None, {'frame': {'duration': 500, 'redraw': False},
                         'fromcurrent': True, 'transition': {'duration': 300, 
                                                             'easing': 'quadratic-in-out'}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration':0, 'redraw': False}, 'mode': 'immediate',
                'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
    ]
plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# <div>
#
#
#             <div id="c44414c3-66de-4f4f-a875-7bca2d1f3aa8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c44414c3-66de-4f4f-a875-7bca2d1f3aa8")) {
#                     Plotly.newPlot(
#                         'c44414c3-66de-4f4f-a875-7bca2d1f3aa8',
#                         [{"mode": "markers", "text": ["Albania", "Senegal", "Saudi Arabia", "Russian Federation", "Qatar", "Peru", "Panama", "Pakistan", "Oman", "Nigeria", "Serbia", "Niger", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Mauritania", "Maldives", "Madagascar", "Libya", "Nicaragua", "Lebanon", "Seychelles", "Solomon Islands", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Vanuatu", "United Arab Emirates", "Singapore", "Ukraine", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "South Sudan", "South Africa", "Turkey", "Bhutan", "Kuwait", "Kazakhstan", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Vanuatu", "United Arab Emirates", "Ukraine", "Turkey", "Belize", "Tunisia", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "South Sudan", "South Africa", "Solomon Islands", "Singapore", "Trinidad and Tobago", "Kiribati", "Benin", "Bosnia and Herzegovina", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Grenada", "Georgia", "Bhutan", "Ecuador", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Brazil", "Botswana", "Dominican Republic", "Seychelles", "Bosnia and Herzegovina", "Brazil", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Algeria", "Albania", "Botswana", "Vanuatu", "Ukraine", "Turkey", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Sudan", "Sri Lanka", "United Arab Emirates", "South Sudan", "Brazil", "Cameroon", "Lebanon", "Kuwait", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Burundi", "Guyana", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Guinea", "Botswana", "South Africa", "Singapore", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Kuwait", "Grenada", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Georgia", "Solomon Islands", "Lebanon", "Madagascar", "Seychelles", "Serbia", "Senegal", "Saudi Arabia", "Russian Federation", "Qatar", "Peru", "Panama", "Pakistan", "Libya", "Oman", "Niger", "Nicaragua", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Mauritania", "Maldives", "Nigeria", "Serbia", "Senegal", "Saudi Arabia", "Vanuatu", "United Arab Emirates", "Ukraine", "Turkey", "Tunisia", "Trinidad and Tobago", "Tonga", "Syrian Arab Republic", "Suriname", "Albania", "Sudan", "South Sudan", "South Africa", "Solomon Islands", "Singapore", "Seychelles", "Serbia", "Senegal", "Saudi Arabia", "Russian Federation", "Sri Lanka", "Qatar", "Algeria", "Bahrain", "Guyana", "Guinea", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Antigua and Barbuda", "Chad", "Cameroon", "Burundi", "Brazil", "Botswana", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Central African Republic", "Honduras", "Peru", "Pakistan", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Cote d'Ivoire", "Comoros", "Colombia", "Chad", "Central African Republic", "Guinea", "Cameroon", "Brazil", "Botswana", "Bosnia and Herzegovina", "Bhutan", "Benin", "Belize", "Bangladesh", "Bahrain", "Antigua and Barbuda", "Burundi", "Panama", "Guyana", "India", "Oman", "Nigeria", "Niger", "Nicaragua", "Nepal", "Myanmar", "Morocco", "Montenegro", "Mexico", "Honduras", "Mauritania", "Madagascar", "Libya", "Lebanon", "Kuwait", "Kiribati", "Kazakhstan", "Jordan", "Jamaica", "Israel", "Maldives", "India", "Israel", "Jamaica", "Israel", "India", "Honduras", "Guyana", "Guinea", "Grenada", "Georgia", "Ecuador", "Dominican Republic", "Jamaica", "Cote d'Ivoire", "Colombia", "Chad", "Central African Republic", "Cameroon", "Burundi", "Brazil ...

# %%
from bubbly.bubbly import make_grid, set_layout, get_trace

# Define the new variable
size_column = 'values' 

# Make the grid
years = dataset[time_column].unique()

col_name_template = '{}+{}_grid'
column_names = [x_column, y_column, bubble_column, size_column]
grid = make_grid(dataset, column_names, time_column, years)
    
# Set the layout
figure, sliders_dict = set_layout(x_title='Target', y_title='Vaccinated', 
            title='IPV1 Vaccination', x_logscale=True, y_logscale=False, 
            show_slider=True, slider_scale=years, show_button=True, show_legend=False, 
            height=650)
# Add the base frame
year = min(years)
col_name_template_year = col_name_template.format(year, {})
trace = get_trace(grid=grid, col_name_template=col_name_template_year, 
                    x_column=x_column, y_column=y_column, 
                    bubble_column=bubble_column, size_column=size_column)
figure['data'].append(trace)


# Add time frames
for year in years:
    frame = {'data': [], 'name': str(year)}
    col_name_template_year = col_name_template.format(year, {})
    trace = get_trace(grid=grid, col_name_template=col_name_template_year, 
                    x_column=x_column, y_column=y_column, 
                    bubble_column=bubble_column, size_column=size_column)
    frame['data'].append(trace)
    figure['frames'].append(frame) 
    add_slider_steps(sliders_dict, year)

# Set the layout once more
figure['layout']['xaxis']['autorange'] = True
figure['layout']['yaxis']['range'] = [20, 200]
figure['layout']['sliders'] = [sliders_dict]

#print(frame)
# Plot the animation
plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# <div>
#
#
#             <div id="325a2203-f2d7-4c5a-a56d-7ad172e372bc" class="plotly-graph-div" style="height:650px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("325a2203-f2d7-4c5a-a56d-7ad172e372bc")) {
#                     Plotly.newPlot(
#                         '325a2203-f2d7-4c5a-a56d-7ad172e372bc',
#                         [{"marker": {"size": [3148281, 13033809, 28267685, 142960868, 2035871, 29264318, 3706483, 183340592, 3251108, 162805071, 7234099, 17114761, 27041437, 50990615, 32781850, 620079, 115695473, 3598648, 380495, 21743967, 6247439, 5903039, 5202343, 87441, 541521, 9729248, 338000, 151007807, 1299943, 90409, 37383887, 2900401, 242653, 8946777, 5183688, 45706100, 10741880, 1336178, 103562, 21082966, 535179, 35349681, 20398670, 9830698, 52004172, 73443863, 701583, 3168060, 16557201, 149273778, 1278151, 89253, 36661444, 2905195, 236211, 8549988, 45870700, 72326988, 330237, 10635244, 103986, 21362529, 529131, 34545013, 20261737, 9508364, 51216964, 527861, 5076732, 1328147, 104728, 9460830, 3661175, 7663131, 2825929, 7765800, 1250288729, 8480671, 752028, 10420471, 106796, 3756441, 693298, 15243883, 21028655, 706569, 45663099, 12360989, 4418636, 20906388, 8958406, 197514534, 2015402, 9813210, 89770, 3604972, 199287296, 3542605, 710238, 10004588, 345715, 152764676, 1315029, 91516, 38140132, 2895092, 2062536, 249499, 45593300, 74653016, 10847002, 1344817, 102737, 20442541, 541245, 36193783, 20425000, 9141596, 10113647, 201035903, 22077298, 5914621, 3526378, 107890, 17035550, 8520420, 2858709, 8059500, 1280846129, 8798521, 9540289, 759285, 108170, 3717668, 15707474, 10048224, 22087505, 741505, 46497267, 13220424, 4447942, 10892810, 2039551, 52834005, 5312437, 106370, 16792089, 8090872, 2842132, 7910500, 1265782790, 8640691, 755399, 10652029, 3348853, 107446, 15474102, 9930911, 21547188, 723871, 46076848, 12784750, 4436415, 21485266, 9245988, 3728874, 556064, 5538634, 22346641, 88303, 7199077, 13401991, 29155187, 143201676, 2196074, 29506788, 3770624, 187281475, 6285750, 3498029, 17795191, 5982526, 26989862, 51413698, 33241898, 620601, 117274155, 3706554, 397237, 167228767, 7291436, 12678148, 27421461, 224704, 7089487, 46258200, 70418604, 10414433, 1314443, 103379, 20664038, 517123, 2927519, 33060837, 8736939, 49779471, 503360, 4839396, 86956, 7350222, 12004701, 25888541, 142742350, 19983984, 1436665, 35333881, 1185076, 747718, 9964469, 105789, 3814419, 14774424, 9576737, 20059147, 673252, 44750054, 86746, 11560147, 19789919, 8397668, 193886508, 1953498, 3735938, 678323, 8944708, 314655, 145924797, 4337625, 8150775, 28562317, 171648986, 105456, 3848449, 14535739, 9458075, 19605569, 657229, 44254975, 11183588, 4273366, 9738792, 19252666, 192030362, 1915639, 3754271, 671613, 8696921, 306823, 144304167, 1114641, 85397, 8126102, 3516204, 746817, 1200669765, 2750963, 150269623, 15250908, 5667432, 26666576, 49929642, 31536811, 616969, 110815271, 7980955, 3296238, 19996473, 6058748, 4764741, 2656009, 98761, 15674000, 6556478, 2781876, 7308800, 343452, 1217726215, 7485600, 2795837, 7623600, 1234281170, 8317470, 749436, 10192176, 106233, 3786695, 15011117, 9695121, 2810460, 20532950, 45222700, 11952136, 4386768, 20341241, 8675602, 195713635, 1987105, 3705472, 685503, 689692, 9199259, 7261539, 102927, 142849449, 1856327, 29027674, 3642687, 179424641, 3041434, 158503197, 16464025, 5824065, 16321872, 27013212, 32343389, 619428, 114092963, 3494195, 365734, 21151640, 6197663, 4953061, 2991884, 50600818, 322464, 147575430, 1240860, 3579215, 175525609, 2876186, 154324933, 15843133, 5745526, 26883535, 50250367, 31929087, 28792655, 618294, 3393409, 353398, 20569117, 6133984, 4813026, 2821045, 100930, 16092822, 6893260, 112463887, 1654950, 142785342, 26630303, 88028, 35977455, 2913021, 230247, 7917372, 46053300, 71321399, 10525694, 1320930, 103890, 21205873, 523111, 33783788, 20123508, 9142259, 50477011, 515181, 4987573, 87298, 7320807, 12335084, 6320359, 22961253, 415593, 3817494, 10513131, 24437469, 813892, 48901066, 15016773, 4596028, 24566045, 10827024, 207833831, 16785361, 2205128, 745568, 11175204, 375769, 159670593, 1494074, 95426, 41389198, 2873457, 278330, 3351527, 9360980, 3728004, 12067539, 6384855, 27627124, 53382581, 35581294, 622373, 124777324, 4282574, 496402, 25570540, 110874, 6580724, 4056097, 114158, 18037776, 9779173, 29 ...
