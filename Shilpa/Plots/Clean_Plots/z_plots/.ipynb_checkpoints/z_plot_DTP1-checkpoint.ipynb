# %%
import pandas as pd
import numpy as np
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

# %%
dtp1 = "/Users/shilpa/Desktop/Desktop/RICE_DATA/Global_Vaccination_Progress/Shilpa/Plots/Clean_Plots/DTP1/df_DTP1_All_countries copy.csv"
DTP1 = pd.read_csv(dtp1)
DTP1.head(5)
reversed_df_DTP1= DTP1.sort_values(['year'], ascending= True)
reversed_df_DTP1
# Out:
#                           Index           country  year Vaccine Subgroup  \
# 77219          1997DTP1Zimbabwe          Zimbabwe  1997    DTP1     ESAR
# 57834           1997DTP1Romania           Romania  1997    DTP1   CEECIS
# 57835           1997DTP1Romania           Romania  1997    DTP1   CEECIS
# 57836           1997DTP1Romania           Romania  1997    DTP1   CEECIS
# 57837           1997DTP1Romania           Romania  1997    DTP1   CEECIS
# ...                         ...               ...   ...     ...      ...
# 53972  2018DTP1Papua New Guinea  Papua New Guinea  2018    DTP1     EAPR
# 53973  2018DTP1Papua New Guinea  Papua New Guinea  2018    DTP1     EAPR
# 53974  2018DTP1Papua New Guinea  Papua New Guinea  2018    DTP1     EAPR
# 53976  2018DTP1Papua New Guinea  Papua New Guinea  2018    DTP1     EAPR
# 0           2018DTP1Afghanistan       Afghanistan  2018    DTP1     ROSA
#
#        Coverage  Vaccinated   Target    values
# ...

# %%
from bubbly.bubbly import bubbleplot 

figure = bubbleplot(dataset=reversed_df_DTP1, x_column='Target', y_column='Coverage', 
    bubble_column='country', time_column='year', size_column='values', color_column='Subgroup',
    x_title="Target", y_title="% covered", title='DTP1 vaccination',
    x_logscale=True, scale_bubble=3, height=650)

plotly.offline.iplot(figure, config={'scrollzoom': True})
