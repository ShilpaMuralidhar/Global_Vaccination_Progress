# %%
import pandas as pd
import numpy as np
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
wuenic = "/Users/shilpa/Desktop/Desktop/RICE_DATA/Global_Vaccination_Progress/Shilpa/Plots/Clean_Plots/IPV/df_IPV1_All_countries.csv"
IPV1 = pd.read_csv(wuenic)
IPV1.head(5)
df_IPV1= IPV1.sort_values(['year'], ascending= True)
df_IPV1
# Out:
#       Unnamed: 0  Unnamed: 0.1     0  Unnamed: 0.1.1  \
# 0              0           132   132             203
# 1032           9          1210  1210            4119
# 1031         769          8568  8568           34561
# 1030           1           220   220             411
# 1029           2           330   330             939
# ...          ...           ...   ...             ...
# 6858        8599          8491  8491           34338
# 6859        8592          7963  7963           32065
# 6860        8582          7303  7303           29738
# 6842        8562          5873  5873           23431
# 8601        8601          8601  8601           35261
#
#                             Index              country  year Vaccine Subgroup  \
# 0                 2015IPV1Albania              Albania  2015    IPV1   CEECIS
# 1032             2015IPV1Botswana             Botswana  2015    IPV1     ESAR
# 1031              2015IPV1Vanuatu              Vanuatu  2015    IPV1     EAPR
# 1030              2015IPV1Algeria              Algeria  2015    IPV1     MENA
# 1029  2015IPV1Antigua and Barbuda  Antigua and Barbuda  2015    IPV1     LACR
# ...                           ...                  ...   ...     ...      ...
# 6858           2018IPV1Uzbekistan           Uzbekistan  2018    IPV1   CEECIS
# 6859  2018IPV1Trinidad and Tobago  Trinidad and Tobago  2018    IPV1     LACR
# 6860          2018IPV1South Sudan          South Sudan  2018    IPV1     ESAR
# 6842             2018IPV1Pakistan             Pakistan  2018    IPV1     ROSA
# 8601               2018IPV1Zambia               Zambia  2018    IPV1     ESAR
#
#       Coverage  Vaccinated   Target     values
# 0           99       35000    35000    3148281
# 1032         8        4000    55000    1540425
# 1031         4         500     8000     219472
# 1030         8       79000   991000   29742979
# 1029        21         500     1000      71704
# ...        ...         ...      ...        ...
# 6858        56      382000   682000   32955400
# 6859        99       17000    18000    1389858
# 6860        34      123000   362000   10975920
# 6842        75     4226000  5634000  212215030
# 8601        36      216000   601000   17351822
#
# [8602 rows x 13 columns]

# %%
df_IPV1.to_csv('../Plots/df_IPV1_All_countries.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9e197d74c87c> in <module>
# ----> 1 df_IPV1.to_csv('../Plots/df_IPV1_All_countries.csv')
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Plots/df_IPV1_All_countries.csv'

# %%
dataset = df_IPV1
x_column = 'Target'
y_column = 'Coverage'
size_column = 'values'
bubble_column = 'country'
time_column = 'year'

# %%
# Get the years in the dataset
years = dataset[time_column].unique()

# Make the grid
grid = pd.DataFrame()
col_name_template = '{year}+{header}_grid'
for year in years:
    dataset_by_year = dataset[(dataset['year'] == int(year))]
    for col_name in [x_column, y_column, bubble_column]:
        # Each column name is unique
        temp = col_name_template.format(
            year=year, header=col_name
        )
        if dataset_by_year[col_name].size != 0:
            grid = grid.append({'value': list(dataset_by_year[col_name]), 'key': temp}, 
                               ignore_index=True)

grid.sample(5)
# Out:
#                   key                                              value
# 8   2017+country_grid  [Afghanistan, Albania, Algeria, Antigua and Ba...
# 5   2016+country_grid  [Benin, Vanuatu, Bahrain, Equatorial Guinea, B...
# 2   2015+country_grid  [Albania, Botswana, Vanuatu, Algeria, Antigua ...
# 11  2018+country_grid  [Barbados, Algeria, Bosnia and Herzegovina, Al...
# 0    2015+Target_grid  [35000, 55000, 8000, 991000, 1000, 21000, 2906...

# %%
# Define figure
figure = {
    'data': [],
    'layout': {},
    'frames': []
}

# Get the earliest year
year = min(years)

# Make the trace
trace = {
    'x': grid.loc[grid['key']==col_name_template.format(
        year=year, header=x_column
    ), 'value'].values[0], 
    'y': grid.loc[grid['key']==col_name_template.format(
        year=year, header=y_column
    ), 'value'].values[0],
    'mode': 'markers',
    'text': grid.loc[grid['key']==col_name_template.format(
        year=year, header=bubble_column
    ), 'value'].values[0]
}
# Append the trace to the figure
figure['data'].append(trace)

# Plot the figure
plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# //anaconda3/lib/python3.7/site-packages/plotly/offline/offline.py:156: UserWarning:
#
#
# Unrecognized config options supplied: ['scrollzoom']
# <div>
#
#
#             <div id="5f81bc73-8ac3-41bf-be5e-bf3bb61f9c91" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5f81bc73-8ac3-41bf-be5e-bf3bb61f9c91")) {
#                     Plotly.newPlot(
#                         '5f81bc73-8ac3-41bf-be5e-bf3bb61f9c91',
#                         [{"mode": "markers", "text": ["Albania", "Botswana", "Vanuatu", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Benin", "Bhutan", "Oman", "Bosnia and Herzegovina", "Georgia", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Dominican Republic", "Brazil", "Ecuador", "Grenada", "Niger", "Libya", "Honduras", "India", "Israel", "Jamaica", "Jordan", "Kazakhstan", "Kiribati", "Kuwait", "Guyana", "Lebanon", "Guinea", "Maldives", "Mauritania", "Mexico", "Montenegro", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Madagascar", "Guyana", "Nigeria", "Guinea", "South Africa", "Peru", "Qatar", "Russian Federation", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Singapore", "Panama", "Solomon Islands", "United Arab Emirates", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "South Sudan", "Pakistan", "Vanuatu", "Grenada", "Burundi", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Benin", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Algeria", "Brazil", "Albania", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Dominican Republic", "Ecuador", "Georgia", "Cameroon", "Ukraine", "Honduras", "India", "Maldives", "Israel", "Jamaica", "Jordan", "Kazakhstan", "Kiribati", "Kuwait", "Lebanon", "Libya", "Peru", "Madagascar", "Panama", "Mexico", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Mauritania", "Pakistan", "Qatar", "Algeria", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Russian Federation", "Sudan", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Suriname", "India", "Antigua and Barbuda", "Bangladesh", "Colombia", "Benin", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Belize", "Chad", "Israel", "Cote d'Ivoire", "Dominican Republic", "Ecuador", "Georgia", "Grenada", "Guinea", "Guyana", "Honduras", "Comoros", "Bahrain", "Jamaica", "Qatar", "Morocco", "Kiribati", "Kuwait", "Lebanon", "Libya", "Madagascar", "Maldives", "Mauritania", "Mexico", "Kazakhstan", "Montenegro", "Jordan", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Panama", "Peru", "Myanmar", "Russian Federation", "Saudi Arabia", "Senegal", "Seychelles", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Jordan", "Kazakhstan", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Belize", "Dominican Republic", "Ecuador", "Georgia", "Grenada", "Guinea", "Guyana", "Honduras", "India", "Israel", "Jamaica", "Benin", "Cote d'Ivoire", "Kiribati", "Tunisia", "Lebanon", "Libya", "Madagascar", "Maldives", "Mauritania", "Mexico", "Montenegro", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Panama", "Peru", "Qatar", "Russian Federation", "Saudi Arabia", "Senegal", "Benin", "Kuwait", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Serbia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Seychelles", "Serbia", "Bhutan", "Botswana", "Ecuador", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Singapore", "Dominican Republic", "Kiribati", "Grenada", "Guinea", "Guyana", "Honduras", "India", "Israel", "Jamaica", "Jordan",  ...

# %%
# Get the max and min range of both axes
xmin = min(np.log10(dataset[x_column]))*0.98
xmax = max(np.log10(dataset[x_column]))*1.02
ymin = min(dataset[y_column])*0.75
ymax = max(dataset[y_column])*1.25

# Modify the layout
figure['layout']['xaxis'] = {'title': 'Target', 'type': 'log', 
                             'range': [xmin, xmax]}   
figure['layout']['yaxis'] = {'title': '%Vaccinated', 
                             'range': [ymin, ymax]} 
figure['layout']['title'] = 'Global IPV1 Vaccination'
figure['layout']['showlegend'] = False
figure['layout']['hovermode'] = 'closest'
plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# <div>
#
#
#             <div id="acdcfb18-861c-468f-ae65-ff2f830e479c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("acdcfb18-861c-468f-ae65-ff2f830e479c")) {
#                     Plotly.newPlot(
#                         'acdcfb18-861c-468f-ae65-ff2f830e479c',
#                         [{"mode": "markers", "text": ["Albania", "Botswana", "Vanuatu", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Benin", "Bhutan", "Oman", "Bosnia and Herzegovina", "Georgia", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Dominican Republic", "Brazil", "Ecuador", "Grenada", "Niger", "Libya", "Honduras", "India", "Israel", "Jamaica", "Jordan", "Kazakhstan", "Kiribati", "Kuwait", "Guyana", "Lebanon", "Guinea", "Maldives", "Mauritania", "Mexico", "Montenegro", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Madagascar", "Guyana", "Nigeria", "Guinea", "South Africa", "Peru", "Qatar", "Russian Federation", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Singapore", "Panama", "Solomon Islands", "United Arab Emirates", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "South Sudan", "Pakistan", "Vanuatu", "Grenada", "Burundi", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Benin", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Algeria", "Brazil", "Albania", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Dominican Republic", "Ecuador", "Georgia", "Cameroon", "Ukraine", "Honduras", "India", "Maldives", "Israel", "Jamaica", "Jordan", "Kazakhstan", "Kiribati", "Kuwait", "Lebanon", "Libya", "Peru", "Madagascar", "Panama", "Mexico", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Mauritania", "Pakistan", "Qatar", "Algeria", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Russian Federation", "Sudan", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Suriname", "India", "Antigua and Barbuda", "Bangladesh", "Colombia", "Benin", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Belize", "Chad", "Israel", "Cote d'Ivoire", "Dominican Republic", "Ecuador", "Georgia", "Grenada", "Guinea", "Guyana", "Honduras", "Comoros", "Bahrain", "Jamaica", "Qatar", "Morocco", "Kiribati", "Kuwait", "Lebanon", "Libya", "Madagascar", "Maldives", "Mauritania", "Mexico", "Kazakhstan", "Montenegro", "Jordan", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Panama", "Peru", "Myanmar", "Russian Federation", "Saudi Arabia", "Senegal", "Seychelles", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Jordan", "Kazakhstan", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Belize", "Dominican Republic", "Ecuador", "Georgia", "Grenada", "Guinea", "Guyana", "Honduras", "India", "Israel", "Jamaica", "Benin", "Cote d'Ivoire", "Kiribati", "Tunisia", "Lebanon", "Libya", "Madagascar", "Maldives", "Mauritania", "Mexico", "Montenegro", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Panama", "Peru", "Qatar", "Russian Federation", "Saudi Arabia", "Senegal", "Benin", "Kuwait", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Serbia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Seychelles", "Serbia", "Bhutan", "Botswana", "Ecuador", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Singapore", "Dominican Republic", "Kiribati", "Grenada", "Guinea", "Guyana", "Honduras", "India", "Israel", "Jamaica", "Jordan",  ...

# %%
for year in years:
    # Make a frame for each year
    frame = {'data': [], 'name': str(year)}
    
    # Make a trace for each frame
    trace = {
        'x': grid.loc[grid['key']==col_name_template.format(
            year=year, header=x_column
        ), 'value'].values[0],
        'y': grid.loc[grid['key']==col_name_template.format(
            year=year, header=y_column
        ), 'value'].values[0],
        'mode': 'markers',
        'text': grid.loc[grid['key']==col_name_template.format(
            year=year, header=bubble_column
        ), 'value'].values[0],
        'type': 'scatter'
    }
    # Add trace to the frame
    frame['data'].append(trace)
    # Add frame to the figure
    figure['frames'].append(frame) 

plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# <div>
#
#
#             <div id="93fb5973-c979-4b7c-a058-4d103ee6f5c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("93fb5973-c979-4b7c-a058-4d103ee6f5c8")) {
#                     Plotly.newPlot(
#                         '93fb5973-c979-4b7c-a058-4d103ee6f5c8',
#                         [{"mode": "markers", "text": ["Albania", "Botswana", "Vanuatu", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Benin", "Bhutan", "Oman", "Bosnia and Herzegovina", "Georgia", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Dominican Republic", "Brazil", "Ecuador", "Grenada", "Niger", "Libya", "Honduras", "India", "Israel", "Jamaica", "Jordan", "Kazakhstan", "Kiribati", "Kuwait", "Guyana", "Lebanon", "Guinea", "Maldives", "Mauritania", "Mexico", "Montenegro", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Madagascar", "Guyana", "Nigeria", "Guinea", "South Africa", "Peru", "Qatar", "Russian Federation", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Singapore", "Panama", "Solomon Islands", "United Arab Emirates", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "South Sudan", "Pakistan", "Vanuatu", "Grenada", "Burundi", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Benin", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Algeria", "Brazil", "Albania", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Dominican Republic", "Ecuador", "Georgia", "Cameroon", "Ukraine", "Honduras", "India", "Maldives", "Israel", "Jamaica", "Jordan", "Kazakhstan", "Kiribati", "Kuwait", "Lebanon", "Libya", "Peru", "Madagascar", "Panama", "Mexico", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Mauritania", "Pakistan", "Qatar", "Algeria", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Russian Federation", "Sudan", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Suriname", "India", "Antigua and Barbuda", "Bangladesh", "Colombia", "Benin", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Belize", "Chad", "Israel", "Cote d'Ivoire", "Dominican Republic", "Ecuador", "Georgia", "Grenada", "Guinea", "Guyana", "Honduras", "Comoros", "Bahrain", "Jamaica", "Qatar", "Morocco", "Kiribati", "Kuwait", "Lebanon", "Libya", "Madagascar", "Maldives", "Mauritania", "Mexico", "Kazakhstan", "Montenegro", "Jordan", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Panama", "Peru", "Myanmar", "Russian Federation", "Saudi Arabia", "Senegal", "Seychelles", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Jordan", "Kazakhstan", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Belize", "Dominican Republic", "Ecuador", "Georgia", "Grenada", "Guinea", "Guyana", "Honduras", "India", "Israel", "Jamaica", "Benin", "Cote d'Ivoire", "Kiribati", "Tunisia", "Lebanon", "Libya", "Madagascar", "Maldives", "Mauritania", "Mexico", "Montenegro", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Panama", "Peru", "Qatar", "Russian Federation", "Saudi Arabia", "Senegal", "Benin", "Kuwait", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Serbia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Seychelles", "Serbia", "Bhutan", "Botswana", "Ecuador", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Singapore", "Dominican Republic", "Kiribati", "Grenada", "Guinea", "Guyana", "Honduras", "India", "Israel", "Jamaica", "Jordan",  ...

# %%
figure['layout']['sliders'] = {
    'args': [
        'slider.value', {
            'duration': 400,
            'ease': 'cubic-in-out'
        }
    ],
    'initialValue': min(years),
    'plotlycommand': 'animate',
    'values': years,
    'visible': True
}
sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Year:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': []
}

from bubbly.bubbly import add_slider_steps

for year in years:
    add_slider_steps(sliders_dict, year)
    
figure['layout']['sliders'] = [sliders_dict]
plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# <div>
#
#
#             <div id="e9dad879-b0fc-4044-8034-baf7a0ddb35e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e9dad879-b0fc-4044-8034-baf7a0ddb35e")) {
#                     Plotly.newPlot(
#                         'e9dad879-b0fc-4044-8034-baf7a0ddb35e',
#                         [{"mode": "markers", "text": ["Albania", "Botswana", "Vanuatu", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Benin", "Bhutan", "Oman", "Bosnia and Herzegovina", "Georgia", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Dominican Republic", "Brazil", "Ecuador", "Grenada", "Niger", "Libya", "Honduras", "India", "Israel", "Jamaica", "Jordan", "Kazakhstan", "Kiribati", "Kuwait", "Guyana", "Lebanon", "Guinea", "Maldives", "Mauritania", "Mexico", "Montenegro", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Madagascar", "Guyana", "Nigeria", "Guinea", "South Africa", "Peru", "Qatar", "Russian Federation", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Singapore", "Panama", "Solomon Islands", "United Arab Emirates", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "South Sudan", "Pakistan", "Vanuatu", "Grenada", "Burundi", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Benin", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Algeria", "Brazil", "Albania", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Dominican Republic", "Ecuador", "Georgia", "Cameroon", "Ukraine", "Honduras", "India", "Maldives", "Israel", "Jamaica", "Jordan", "Kazakhstan", "Kiribati", "Kuwait", "Lebanon", "Libya", "Peru", "Madagascar", "Panama", "Mexico", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Mauritania", "Pakistan", "Qatar", "Algeria", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Russian Federation", "Sudan", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Suriname", "India", "Antigua and Barbuda", "Bangladesh", "Colombia", "Benin", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Belize", "Chad", "Israel", "Cote d'Ivoire", "Dominican Republic", "Ecuador", "Georgia", "Grenada", "Guinea", "Guyana", "Honduras", "Comoros", "Bahrain", "Jamaica", "Qatar", "Morocco", "Kiribati", "Kuwait", "Lebanon", "Libya", "Madagascar", "Maldives", "Mauritania", "Mexico", "Kazakhstan", "Montenegro", "Jordan", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Panama", "Peru", "Myanmar", "Russian Federation", "Saudi Arabia", "Senegal", "Seychelles", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Jordan", "Kazakhstan", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Belize", "Dominican Republic", "Ecuador", "Georgia", "Grenada", "Guinea", "Guyana", "Honduras", "India", "Israel", "Jamaica", "Benin", "Cote d'Ivoire", "Kiribati", "Tunisia", "Lebanon", "Libya", "Madagascar", "Maldives", "Mauritania", "Mexico", "Montenegro", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Panama", "Peru", "Qatar", "Russian Federation", "Saudi Arabia", "Senegal", "Benin", "Kuwait", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Serbia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Seychelles", "Serbia", "Bhutan", "Botswana", "Ecuador", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Singapore", "Dominican Republic", "Kiribati", "Grenada", "Guinea", "Guyana", "Honduras", "India", "Israel", "Jamaica", "Jordan",  ...

# %%
figure['layout']['updatemenus'] = [
    {
        'buttons': [
            {
                'args': [None, {'frame': {'duration': 500, 'redraw': False},
                         'fromcurrent': True, 'transition': {'duration': 300, 
                                                             'easing': 'quadratic-in-out'}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration':0, 'redraw': False}, 'mode': 'immediate',
                'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
    ]
plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# <div>
#
#
#             <div id="cfbf8d10-d07f-4eb5-a567-3a60496ba6f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cfbf8d10-d07f-4eb5-a567-3a60496ba6f4")) {
#                     Plotly.newPlot(
#                         'cfbf8d10-d07f-4eb5-a567-3a60496ba6f4',
#                         [{"mode": "markers", "text": ["Albania", "Botswana", "Vanuatu", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Benin", "Bhutan", "Oman", "Bosnia and Herzegovina", "Georgia", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Dominican Republic", "Brazil", "Ecuador", "Grenada", "Niger", "Libya", "Honduras", "India", "Israel", "Jamaica", "Jordan", "Kazakhstan", "Kiribati", "Kuwait", "Guyana", "Lebanon", "Guinea", "Maldives", "Mauritania", "Mexico", "Montenegro", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Madagascar", "Guyana", "Nigeria", "Guinea", "South Africa", "Peru", "Qatar", "Russian Federation", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Singapore", "Panama", "Solomon Islands", "United Arab Emirates", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "South Sudan", "Pakistan", "Vanuatu", "Grenada", "Burundi", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Benin", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Algeria", "Brazil", "Albania", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Dominican Republic", "Ecuador", "Georgia", "Cameroon", "Ukraine", "Honduras", "India", "Maldives", "Israel", "Jamaica", "Jordan", "Kazakhstan", "Kiribati", "Kuwait", "Lebanon", "Libya", "Peru", "Madagascar", "Panama", "Mexico", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Mauritania", "Pakistan", "Qatar", "Algeria", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Russian Federation", "Sudan", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Suriname", "India", "Antigua and Barbuda", "Bangladesh", "Colombia", "Benin", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Belize", "Chad", "Israel", "Cote d'Ivoire", "Dominican Republic", "Ecuador", "Georgia", "Grenada", "Guinea", "Guyana", "Honduras", "Comoros", "Bahrain", "Jamaica", "Qatar", "Morocco", "Kiribati", "Kuwait", "Lebanon", "Libya", "Madagascar", "Maldives", "Mauritania", "Mexico", "Kazakhstan", "Montenegro", "Jordan", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Panama", "Peru", "Myanmar", "Russian Federation", "Saudi Arabia", "Senegal", "Seychelles", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Tunisia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Jordan", "Kazakhstan", "Bhutan", "Bosnia and Herzegovina", "Botswana", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Belize", "Dominican Republic", "Ecuador", "Georgia", "Grenada", "Guinea", "Guyana", "Honduras", "India", "Israel", "Jamaica", "Benin", "Cote d'Ivoire", "Kiribati", "Tunisia", "Lebanon", "Libya", "Madagascar", "Maldives", "Mauritania", "Mexico", "Montenegro", "Morocco", "Myanmar", "Nepal", "Nicaragua", "Niger", "Nigeria", "Oman", "Pakistan", "Panama", "Peru", "Qatar", "Russian Federation", "Saudi Arabia", "Senegal", "Benin", "Kuwait", "Singapore", "Solomon Islands", "South Africa", "South Sudan", "Sri Lanka", "Sudan", "Suriname", "Syrian Arab Republic", "Tonga", "Trinidad and Tobago", "Serbia", "Turkey", "Ukraine", "United Arab Emirates", "Vanuatu", "Albania", "Algeria", "Antigua and Barbuda", "Bahrain", "Bangladesh", "Belize", "Seychelles", "Serbia", "Bhutan", "Botswana", "Ecuador", "Brazil", "Burundi", "Cameroon", "Central African Republic", "Chad", "Colombia", "Comoros", "Cote d'Ivoire", "Singapore", "Dominican Republic", "Kiribati", "Grenada", "Guinea", "Guyana", "Honduras", "India", "Israel", "Jamaica", "Jordan",  ...

# %%
from bubbly.bubbly import make_grid, set_layout, get_trace

# Define the new variable
size_column = 'values' 

# Make the grid
years = dataset[time_column].unique()

col_name_template = '{}+{}_grid'
column_names = [x_column, y_column, bubble_column, size_column]
grid = make_grid(dataset, column_names, time_column, years)
    
# Set the layout
figure, sliders_dict = set_layout(x_title='Target', y_title='Vaccinated', 
            title='IPV1 Vaccination', x_logscale=True, y_logscale=False, 
            show_slider=True, slider_scale=years, show_button=True, show_legend=False, 
            height=650)
# Add the base frame
year = min(years)
col_name_template_year = col_name_template.format(year, {})
trace = get_trace(grid=grid, col_name_template=col_name_template_year, 
                    x_column=x_column, y_column=y_column, 
                    bubble_column=bubble_column, size_column=size_column)
figure['data'].append(trace)


# Add time frames
for year in years:
    frame = {'data': [], 'name': str(year)}
    col_name_template_year = col_name_template.format(year, {})
    trace = get_trace(grid=grid, col_name_template=col_name_template_year, 
                    x_column=x_column, y_column=y_column, 
                    bubble_column=bubble_column, size_column=size_column)
    frame['data'].append(trace)
    figure['frames'].append(frame) 
    add_slider_steps(sliders_dict, year)

# Set the layout once more
figure['layout']['xaxis']['autorange'] = True
figure['layout']['yaxis']['range'] = [20, 200]
figure['layout']['sliders'] = [sliders_dict]

#print(frame)
# Plot the animation
plotly.offline.iplot(figure, config={'scrollzoom': True})
# Out:
# <div>
#
#
#             <div id="8c179422-f5d0-45ea-a7e0-08f0e45966df" class="plotly-graph-div" style="height:650px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8c179422-f5d0-45ea-a7e0-08f0e45966df")) {
#                     Plotly.newPlot(
#                         '8c179422-f5d0-45ea-a7e0-08f0e45966df',
#                         [{"marker": {"size": [3148281, 1540425, 219472, 29742979, 71704, 594931, 120160564, 221580, 6281639, 551709, 2249762, 3736070, 4349913, 6122130, 14344449, 3392436, 7503493, 37723800, 501953, 15130663, 8084407, 167209040, 11951452, 101567, 10178201, 5118007, 6045699, 1000900030, 5836000, 2583916, 4848541, 15333703, 80187, 1710256, 757970, 3658424, 7662075, 263842, 2433563, 94611002, 609520, 27754571, 45027233, 22584775, 4827661, 14347854, 753778, 113457663, 7860781, 42987461, 25210954, 535321, 147915307, 19407142, 9130877, 7596501, 77319, 3796038, 2853913, 379999, 2671362, 18470900, 25413917, 454161, 15175316, 96619, 1259848, 9395123, 60372568, 5411655, 131057431, 174921, 102021, 6185562, 73224, 613700, 122682815, 230244, 6470265, 564377, 3734337, 1575824, 30192754, 169785250, 3128530, 3475492, 7770048, 38364309, 515385, 15589414, 8214426, 12198449, 4243607, 14723768, 50594105, 6220406, 1038058156, 268455, 5971000, 2608873, 4943975, 15071300, 81556, 1831119, 3693520, 5196780, 25658062, 14808791, 2912316, 96056321, 28110443, 45611220, 23057883, 4910647, 10545716, 116319759, 2251864, 2496216, 134843233, 551562, 30623406, 19783304, 9347774, 7567745, 78846, 3927213, 390693, 43682260, 5661942, 18564599, 147670692, 26015521, 15599591, 97032, 1261695, 9509857, 61329676, 50143939, 2813214, 177987, 3108778, 459831, 1019483581, 74674, 125189651, 38999471, 6664098, 577881, 3743354, 1610264, 172318675, 6267124, 15112592, 3558014, 238988, 8053536, 6125000, 16032573, 8343283, 12442115, 4157192, 102432, 8054743, 749674, 6397151, 528848, 636541, 2632675, 570489, 28455509, 82972, 1951636, 3747766, 5275926, 15282521, 273527, 2561585, 97484832, 14928426, 606001, 5031762, 23509964, 4991040, 10929918, 119260063, 2254904, 138624621, 2971196, 26078293, 46181077, 147214392, 20194527, 9568722, 80410, 3958723, 401586, 44338543, 5933882, 18663284, 26626520, 465385, 16013985, 97482, 1263933, 9613588, 62287397, 49673350, 2966034, 181265, 3089027, 31042235, 76016, 664611, 127657854, 5122493, 14883626, 591021, 3751176, 1643334, 174790340, 6378871, 15513945, 3640427, 8355654, 39629968, 542357, 247315, 8471321, 12681123, 4077131, 102833, 8240730, 746715, 6574509, 1056575549, 6289000, 2654701, 6865951, 16454668, 84396, 9708350, 3842778, 5357891, 15766806, 279398, 2630219, 98899845, 604950, 28793679, 46719701, 23941110, 5069302, 11331557, 122283850, 2267973, 142343578, 3030328, 26459944, 592468, 146596557, 20663843, 9797734, 7076733, 2045123, 4027887, 412660, 44967708, 6199394, 18777601, 27275015, 470949, 16410848, 97973, 1267153, 7516346, 63240194, 49175848, 3134062, 184972, 3060173, 31451514, 77212, 697545, 130088702, 255063, 81131, 7540401, 603640, 1674678, 12914667, 177196054, 6525545, 15928910, 3722018, 8678051, 40255967, 555888, 16853026, 4138012, 8598601, 85849, 103249, 8417081, 745206, 6751912, 1075000085, 6439000, 2674702, 5217336, 4014373, 14858335, 2103282, 7503433, 11751365, 16260932, 286306, 2702400, 100298153, 607389, 29126330, 47225120, 24347106, 5443248, 5145366, 3991001, 2294962, 145978402, 3089648, 26799285, 615012, 145976083, 21202642, 10036104, 125394046, 81202, 423944, 3755512, 6447793, 18911730, 27971082, 476579, 16766561, 98487, 1271632, 9793903, 64192243, 48683865, 3302719, 189219, 3051010, 31855109, 78295, 735146, 132478086, 262378, 7295394, 616018, 3759387, 45571274, 1704642, 6704113, 103634, 16357602, 3802128, 9019233, 40875360, 569479, 17231539, 8724975, 13143465, 3978515, 8586074, 179537520, 744789, 6929265, 1093317189, 6570000, 2692845, 5317506, 14858948, 87305, 2136997, 4182205, 5531089, 607662, 294186, 128596076, 2778099, 101684758, 611627, 609828, 29454768, 47702171, 24725627, 5219328, 435432, 12189983, 4175950, 149549700, 3149188, 27100968, 640868, 145306046, 21805313, 10283699, 7496522, 2334858, 83723, 46150913, 181809246, 19062482, 28704778, 482235, 17084632, 99022, 1277213, 65145367, 48202500, 3478777, 6688226, 193920, 32264157, 79300, 778708, 134791603, 269425, 7520555, 627839, 3762173, 1734398, 30396 ...
