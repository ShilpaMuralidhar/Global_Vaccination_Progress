# %%
import pandas as pd
import numpy as np

# %%
DTP1 = "14vaccine_data/2018_DTP1.csv"
DTP1_df = pd.read_csv(DTP1)
DTP1_df
# Out:
#                      unicef_region iso3                             country  \
# 0                       South Asia  AFG                         Afghanistan
# 1    Eastern Europe & Central Asia  ALB                             Albania
# 2       Middle East & North Africa  DZA                             Algeria
# 3                   Western Europe  AND                             Andorra
# 4        Eastern & Southern Africa  AGO                              Angola
# ..                             ...  ...                                 ...
# 190      Latin America & Caribbean  VEN  Venezuela (Bolivarian Republic of)
# 191            East Asia & Pacific  VNM                            Viet Nam
# 192     Middle East & North Africa  YEM                               Yemen
# 193      Eastern & Southern Africa  ZMB                              Zambia
# 194      Eastern & Southern Africa  ZWE                            Zimbabwe
#
# ...

# %%
DTP1 = pd.DataFrame(DTP1_df)
DTP1.head(5)
# Out:
#                    unicef_region iso3      country vaccine  2018  2017  2016  \
# 0                     South Asia  AFG  Afghanistan    DTP1    73    73    73
# 1  Eastern Europe & Central Asia  ALB      Albania    DTP1    99    99    99
# 2     Middle East & North Africa  DZA      Algeria    DTP1    96    95    96
# 3                 Western Europe  AND      Andorra    DTP1    99    99    99
# 4      Eastern & Southern Africa  AGO       Angola    DTP1    67    61    67
#
#    2015  2014  2013  ...  1989  1988  1987  1986  1985  1984  1983  1982  \
# 0    73    73    76  ...  58.0  60.0  50.0  32.0  37.0  39.0  24.0  24.0
# 1    99    99    99  ...  97.0  98.0  98.0  98.0  98.0  98.0  98.0  98.0
# 2    99    99    99  ...  95.0  93.0  92.0  92.0  88.0   NaN   NaN   NaN
# 3    99    99    96  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    65    69    67  ...  41.0  33.0  31.0  31.0  28.0  28.0  25.0   NaN
#
#    1981  1980
# 0   NaN  22.0
# 1  97.0  97.0
# 2   NaN   NaN
# ...

# %%
DTP1.drop(['unicef_region', 'iso3'], axis = 1, inplace = True)
DTP1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-2352fa6c81d4> in <module>
# ----> 1 DTP1.drop(['unicef_region', 'iso3'], axis = 1, inplace = True)
#       2 DTP1
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
DTP1_clean.drop(['unicef_region', 'iso3'], axis = 1, inplace = True)
DTP1_clean
# Out:
#                                 country vaccine  2018  2017  2016  2015  2014  \
# 0                           Afghanistan    DTP1    73    73    73    73    73
# 1                               Albania    DTP1    99    99    99    99    99
# 2                               Algeria    DTP1    96    95    96    99    99
# 3                               Andorra    DTP1    99    99    99    99    99
# 4                                Angola    DTP1    67    61    67    65    69
# ..                                  ...     ...   ...   ...   ...   ...   ...
# 190  Venezuela (Bolivarian Republic of)    DTP1    84    95    97    98    88
# 191                            Viet Nam    DTP1    78    98    96    98    95
# 192                               Yemen    DTP1    75    76    76    77    82
# 193                              Zambia    DTP1    94    95    99    97    96
# 194                            Zimbabwe    DTP1    94    94    94    94    98
#
# ...

# %%
DTP1_clean.to_csv("clean_data/DTP1_clean.csv", index=False)

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:neonate@localhost/Project_2_Vaccine')
connection = engine.connect()

# %%
engine.table_names()
# Out:
# ['DPT3',
#  'HEPB3',
#  'HEPBB',
#  'HIB',
#  'IPV1',
#  'MCV1',
#  'MCV2',
#  'PCV3',
#  'POL3',
#  'RCV1',
#  'ROTAC',
#  'YFV',
#  'PCV_ROTAC',
#  'BCG',
#  'DTP1']

# %%
DTP1.to_sql(name='DTP1', con=engine, if_exists='append', index=False)
