# %%
import pandas as pd
import numpy as np

# %%
less_coverage = "14vaccine_data/<50%coverage.csv"
less_coverage_df = pd.read_csv(less_coverage)
less_coverage_df.head(5)
# Out:
#                  Unnamed: 0 DTP3 MCV1
# 0  Central African Republic  47%  49%
# 1                      Chad  41%  37%
# 2         Equatorial Guinea  25%  30%
# 3                    Guinea  45%  48%
# 4                     Samoa  34%  31%

# %%
less_coverage = pd.DataFrame(less_coverage_df)
less_coverage
# Out:
#                  Unnamed: 0 DTP3 MCV1
# 0  Central African Republic  47%  49%
# 1                      Chad  41%  37%
# 2         Equatorial Guinea  25%  30%
# 3                    Guinea  45%  48%
# 4                     Samoa  34%  31%
# 5                   Somalia  42%  46%
# 6               South Sudan  49%  51%
# 7      Syrian Arab Republic  47%  63%
# 8                   Ukraine  50%  91%

# %%
less_coverage.fillna(0)
# Out:
#                  Unnamed: 0 DTP3 MCV1
# 0  Central African Republic  47%  49%
# 1                      Chad  41%  37%
# 2         Equatorial Guinea  25%  30%
# 3                    Guinea  45%  48%
# 4                     Samoa  34%  31%
# 5                   Somalia  42%  46%
# 6               South Sudan  49%  51%
# 7      Syrian Arab Republic  47%  63%
# 8                   Ukraine  50%  91%
