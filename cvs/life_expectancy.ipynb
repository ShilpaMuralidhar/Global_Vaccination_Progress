# %%
import pandas as pd
import numpy as np

# %%
life_expectancy = "14vaccine_data/life_expectancy.csv"
life_expectancy_df = pd.read_csv(life_expectancy)
life_expectancy_df.head(5)
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                    10/2/2019
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                                 Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                      NaN             NaN         NaN
# 1                                      NaN             NaN         NaN
# 2                                      NaN             NaN         NaN
# 3                           Indicator Name  Indicator Code    1960.000
# 4  Life expectancy at birth, total (years)  SP.DYN.LE00.IN      65.662
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
life_expectancy = pd.DataFrame(life_expectancy_df)
life_expectancy.head(5)
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                    10/2/2019
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                                 Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                      NaN             NaN         NaN
# 1                                      NaN             NaN         NaN
# 2                                      NaN             NaN         NaN
# 3                           Indicator Name  Indicator Code    1960.000
# 4  Life expectancy at birth, total (years)  SP.DYN.LE00.IN      65.662
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
life_expectancy.fillna(0)
# Out:
#            Data Source World Development Indicators  \
# 0                    0                            0
# 1    Last Updated Date                    10/2/2019
# 2                    0                            0
# 3         Country Name                 Country Code
# 4                Aruba                          ABW
# ..                 ...                          ...
# 263             Kosovo                          XKX
# 264        Yemen, Rep.                          YEM
# 265       South Africa                          ZAF
# 266             Zambia                          ZMB
# 267           Zimbabwe                          ZWE
#
#                                   Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                          0               0       0.000
# 1                                          0               0       0.000
# 2                                          0               0       0.000
# ...
